# %% [markdown]
# This notebook uses the <a href="https://v2.docs.influxdata.com/v2.0/reference/client-libraries/">Python-InfluxDB Client Library</a> and FB's Prophet to make forecasts. The dataset and code are taken from the <a href="https://github.com/facebook/prophet/blob/master/notebooks/quick_start.ipynb">quick-start example notebook </a> in the <a href="https://github.com/facebook/prophet">prophet repo</a>.

# %%
import pandas as pd
import time
from datetime import datetime
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-82d1340d588b> in <module>()
#       2 import time
#       3 from datetime import datetime
# ----> 4 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
df = pd.read_csv("Data/data.csv") 
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa03d1c75d80> in <module>()
# ----> 1 df = pd.read_csv("Data/data.csv")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
query = 'from(bucket:"fbprophet")' \
        ' |> range(start:2007-12-10T15:00:00Z, stop:2016-01-20T15:00:00Z)'\
        ' |> filter(fn: (r) => r._measurement == "views")' \
        ' |> filter(fn: (r) => r._field == "y")'
result = client.query_api().query(org="Org", query=query)

# %%
raw = []
for table in result:
    for record in table.records:
        raw.append((record.get_value(), record.get_time()))

# %%
raw[0:5]
# Out:
# [(9.59076113897809,
#   datetime.datetime(2007, 12, 10, 15, 0, tzinfo=datetime.timezone.utc)),
#  (8.51959031601596,
#   datetime.datetime(2007, 12, 11, 15, 0, tzinfo=datetime.timezone.utc)),
#  (8.18367658262066,
#   datetime.datetime(2007, 12, 12, 15, 0, tzinfo=datetime.timezone.utc)),
#  (8.072467369354769,
#   datetime.datetime(2007, 12, 13, 15, 0, tzinfo=datetime.timezone.utc)),
#  (7.893572073504901,
#   datetime.datetime(2007, 12, 14, 15, 0, tzinfo=datetime.timezone.utc))]

# %%
print()
print("=== influxdb query into dataframe ===")
print()
df=pd.DataFrame(raw, columns=['y','ds'], index=None)
df['ds'] = df['ds'].values.astype('<M8[D]')
df.head()
# Out:
# === influxdb query into dataframe ===
#           y         ds
# 0  9.590761 2007-12-10
# 1  8.519590 2007-12-11
# 2  8.183677 2007-12-12
# 3  8.072467 2007-12-13
# 4  7.893572 2007-12-14

# %% [markdown]
# We fit the model by instantiating a new `Prophet` object.  Any settings to the forecasting procedure are passed into the constructor.  Then you call its `fit` method and pass in the historical dataframe. Fitting should take 1-5 seconds.

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# Predictions are then made on a dataframe with a column `ds` containing the dates for which a prediction is to be made. You can get a suitable dataframe that extends into the future a specified number of days using the helper method `Prophet.make_future_dataframe`. By default it will also include the dates from the history, so we will see the model fit as well.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3264 2017-01-14
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18

# %% [markdown]
# The `predict` method will assign each row in `future` a predicted value which it names `yhat`.  If you pass in historical dates, it will provide an in-sample fit. The `forecast` object here is a new dataframe that includes a column `yhat` with the forecast, as well as columns for components and uncertainty intervals.

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3264 2017-01-14  7.827585    7.052645    8.550562
# 3265 2017-01-15  8.209253    7.470475    8.943235
# 3266 2017-01-16  8.534214    7.834082    9.281705
# 3267 2017-01-17  8.321561    7.550338    9.028367
# 3268 2017-01-18  8.153289    7.428931    8.884364

# %%
forecast['measurement'] = "views"
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','measurement']].head()
# Out:
#           ds      yhat  yhat_lower  yhat_upper measurement
# 0 2007-12-10  8.848874    8.245536    9.469667       views
# 1 2007-12-11  8.597372    7.996703    9.219883       views
# 2 2007-12-12  8.392322    7.770665    9.029362       views
# 3 2007-12-13  8.371051    7.743030    8.999857       views
# 4 2007-12-14  8.359002    7.719729    8.962523       views

# %% [markdown]
# You can plot the forecast by calling the `Prophet.plot` method and passing in your forecast dataframe.

# %%
fig1 = m.plot(forecast)

# %%
cp = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper','measurement']].copy()
lines = [str(cp["measurement"][d]) 
         + ",type=forecast" 
         + " " 
         + "yhat=" + str(cp["yhat"][d]) + ","
         + "yhat_lower=" + str(cp["yhat_lower"][d]) + ","
         + "yhat_upper=" + str(cp["yhat_upper"][d])
         + " " + str(int(time.mktime(cp['ds'][d].timetuple()))) + "000000000" for d in range(len(cp))]

# %%
from influxdb_client import InfluxDBClient, Point, WriteOptions
from influxdb_client.client.write_api import SYNCHRONOUS

_write_client = client.write_api(write_options=WriteOptions(batch_size=1000, 
                                                            flush_interval=10_000,
                                                            jitter_interval=2_000,
                                                            retry_interval=5_000))

_write_client.write("0498523df75cd000", "Org", lines)

# %% [markdown]
# To close client:

# %%
_write_client.__del__()
client.__del__()
